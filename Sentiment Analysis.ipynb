# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from IPython.display import clear_output
import time
import torch
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %% [markdown]
# ## Sentiment analysis

# %%
# Load model directly

tokenizer = AutoTokenizer.from_pretrained("lxyuan/distilbert-base-multilingual-cased-sentiments-student")
model = AutoModelForSequenceClassification.from_pretrained("lxyuan/distilbert-base-multilingual-cased-sentiments-student")

inputs = tokenizer(list(df2.review_combined.values[0]), return_tensors="pt", padding=True, truncation=True, max_length=512)

with torch.no_grad():  # Disable gradient calculation for inference
    outputs = model(**inputs)
    logits = outputs.logits

probabilities = torch.softmax(logits, dim=1)
predicted_class = torch.argmax(probabilities, dim=1)

# %%
distilled_student_sentiment_classifier = pipeline(
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", 
    return_all_scores=True
)

distilled_student_sentiment_classifier(list(df2.review_combined.values[:1000]))

# %%
label = {0.0:'positive',1.0:'neutral',2.0:'negative'}
def extract_sentiment(row):
    inputs = tokenizer(row['review_combined'], return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
    probabilities = torch.softmax(logits, dim=1)
    predicted_class = torch.argmax(probabilities, dim=1).tolist()[0]

    return label[predicted_class], probabilities.tolist()[0][predicted_class]

# %% [markdown]
# ### Beauty products

# %%
df = pd.read_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_beauty_v1.tsv", 
sep= '\t', on_bad_lines= 'skip')
df.dropna(subset= ['review_combined'], inplace= True)

# %%
df.head()
# Out:
#    customer_id       review_id  product_id  \
# 0     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 1     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 2     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 3     15727572  r2acmmb1u2wd04  b00koj8zpy
# 4     15727572  r2acmmb1u2wd04  b00koj8zpy
#
#                                        product_title product_category  \
# 0  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 1  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 2  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 3  instyler wet to dry rotating iron, pink, 1-1/4...           beauty
# 4  instyler wet to dry rotating iron, pink, 1-1/4...           beauty
#
#    star_rating  helpful_votes vine verified_purchase  \
# 0            5              3    n                 y
# 1            5              3    n                 y
# 2            5              3    n                 y
# 3            5              0    n                 y
# 4            5              0    n                 y
#
#                                      review_combined
# 0          great product for oily and sensitive skin
# 1  i love this lotion, gentle and does not cause ...
# 2  i have very sensitive oily skin and it does no...
# 3                                         five stars
# 4                                                 ok

# %%
sentiments = df.apply(lambda row: extract_sentiment(row), axis=1, result_type= 'expand')
sentiments.head()
# Out:
#           0         1
# 0  positive  0.943549
# 1  positive  0.895411
# 2  negative  0.464590
# 3  positive  0.840872
# 4  positive  0.673849

# %%
df = pd.concat([df, sentiments], axis= 1)
df.rename(columns= {0:'sentiment_label',1:'sentiment_score'}, inplace= True)
df.head()
# Out:
#    customer_id       review_id  product_id  \
# 0     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 1     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 2     16802621  r2ri5t1qdurkk1  b00dsc9yd6
# 3     15727572  r2acmmb1u2wd04  b00koj8zpy
# 4     15727572  r2acmmb1u2wd04  b00koj8zpy
#
#                                        product_title product_category  \
# 0  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 1  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 2  cerave facial moisturizing lotion pm 3 oz (pac...           beauty
# 3  instyler wet to dry rotating iron, pink, 1-1/4...           beauty
# 4  instyler wet to dry rotating iron, pink, 1-1/4...           beauty
#
#    star_rating  helpful_votes vine verified_purchase  \
# 0            5              3    n                 y
# 1            5              3    n                 y
# 2            5              3    n                 y
# 3            5              0    n                 y
# 4            5              0    n                 y
#
#                                      review_combined sentiment_label  \
# 0          great product for oily and sensitive skin        positive
# 1  i love this lotion, gentle and does not cause ...        positive
# 2  i have very sensitive oily skin and it does no...        negative
# 3                                         five stars        positive
# 4                                                 ok        positive
#
#    sentiment_score
# 0         0.943549
# 1         0.895411
# 2         0.464590
# 3         0.840872
# 4         0.673849

# %%
df.to_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_beauty_v1_with_sentiments.tsv", sep= '\t',
index=False)

# %% [markdown]
# ### Health and Personal products

# %%
df = pd.read_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_health_v1.tsv", 
sep= '\t', on_bad_lines= 'skip')
df.dropna(subset= ['review_combined'], inplace= True)

# %%
sentiments = df.apply(lambda row: extract_sentiment(row), axis=1, result_type= 'expand')
sentiments.head()
# Out:
#           0         1
# 0  positive  0.487475
# 1  positive  0.844414
# 2  positive  0.917963
# 3  positive  0.542714
# 4  positive  0.917963

# %%
df = pd.concat([df, sentiments], axis= 1)
df.rename(columns= {0:'sentiment_label',1:'sentiment_score'}, inplace= True)
df.head()
# Out:
#    customer_id       review_id  product_id  \
# 0     15722143  r2i2pv61y4w6wr  b001bknwfi
# 1     15722143  r2i2pv61y4w6wr  b001bknwfi
# 2     13990039  r3f7uocqloo9v4  b002vwjz6u
# 3     13990039  r3f7uocqloo9v4  b002vwjz6u
# 4     13990039  r3f7uocqloo9v4  b002vwjz6u
#
#                                        product_title        product_category  \
# 0                           bacitraycin plus size 1z  health & personal care
# 1                           bacitraycin plus size 1z  health & personal care
# 2  drive medical economy removable top i. v. pole...  health & personal care
# 3  drive medical economy removable top i. v. pole...  health & personal care
# 4  drive medical economy removable top i. v. pole...  health & personal care
#
#    star_rating  helpful_votes vine verified_purchase  \
# 0            5              0    n                 y
# 1            5              0    n                 y
# 2            4              2    n                 y
# 3            4              2    n                 y
# 4            4              2    n                 y
#
#                                      review_combined sentiment_label  \
# 0                            first aid kit must have        positive
# 1  provides excellent protection from infection w...        positive
# 2                           well made and works well        positive
# 3                                  i needed this to         positive
# 4                           well made and works well        positive
#
#    sentiment_score
# 0         0.487475
# 1         0.844414
# 2         0.917963
# 3         0.542714
# 4         0.917963

# %%
df.to_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_health_v1_with_sentiments.tsv", sep= '\t',
index=False)

# %% [markdown]
# ### Pet products

# %%
df = pd.read_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_pet_v1.tsv", 
sep= '\t', on_bad_lines= 'skip')
df.dropna(subset= ['review_combined'], inplace= True)

# %%
sentiments = df.apply(lambda row: extract_sentiment(row), axis=1, result_type= 'expand')
sentiments.head()
# Out:
#           0         1
# 0  positive  0.427189
# 1  positive  0.371213
# 2  positive  0.935705
# 3  positive  0.472556
# 4  positive  0.746440

# %%
df = pd.concat([df, sentiments], axis= 1)
df.rename(columns= {0:'sentiment_label',1:'sentiment_score'}, inplace= True)
df.head()
# Out:
#    customer_id       review_id  product_id  \
# 0      1713538   rxfiy0irg9f79  b00cb8dy1g
# 1      1713538   rxfiy0irg9f79  b00cb8dy1g
# 2     52422157  r2qcw7x0dcb826  b00cd535lq
# 3     52422157  r2qcw7x0dcb826  b00cd535lq
# 4     27426860  r1mam2vv5z49jw  b0018mm8rc
#
#                                        product_title product_category  \
# 0  p.l soft sponge strawberry small cotton soft d...     pet products
# 1  p.l soft sponge strawberry small cotton soft d...     pet products
# 2  dog glucosamine for dogs with chondroitin & ms...     pet products
# 3  dog glucosamine for dogs with chondroitin & ms...     pet products
# 4  petnation port-a-crate e2 indoor/outdoor pet home     pet products
#
#    star_rating  helpful_votes vine verified_purchase  \
# 0            3              0    n                 y
# 1            3              0    n                 y
# 2            4              1    n                 n
# 3            4              1    n                 n
# 4            3              2    n                 y
#
#                                      review_combined sentiment_label  \
# 0                                           to small        positive
# 1                         it was to small for my pet        positive
# 2                          our dogs love these chews        positive
# 3  i have to say i was concerned at first when i ...        positive
# 4                     quality and design flaws found        positive
#
#    sentiment_score
# 0         0.427189
# 1         0.371213
# 2         0.935705
# 3         0.472556
# 4         0.746440

# %%
df.to_csv(r"C:\Users\91962\Downloads\Course Material\CS9873-BrainInspiredAI\processed_expanded_stratified_reviews_pet_v1_with_sentiments.tsv", sep= '\t',
index=False)
